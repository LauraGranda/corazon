# %% [markdown]
# ## Title
#
# ### By:
# Laura Granda
#
# ### Date:
# 2026-02-21
#
# ### Description:
#
# Trabajo uno dataset corazon

# %% [markdown]
# ## 📚 Import  libraries

# %%
# base libraries for data scienceggs

import pandas as pd

# %%
url_data = "https://www.openml.org/data/get_csv/16826755/phpMYEkMl"
titanic_df = pd.read_csv(url_data, low_memory=False)  # no parsing of mixed types
titanic_df.info()
